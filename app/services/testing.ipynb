# %%
from app.services.parser import parser

diff = """diff --git a/src/calc.py b/src/calc.py
--- a/src/calc.py
+++ b/src/calc.py
@@ -1,3 +1,3 @@
 def add(a, b):
-    return a+b
+    return a + b
"""

files = parser(diff)
print(f"Archivos: {len(files)}")
print(f"Ruta: {files[0].path}")
print(f"Agregadas: {[l.content for l in files[0].added_lines]}")
print(f"Con línea nº: {[(l.content, l.new_lineno) for l in files[0].added_lines]}")
